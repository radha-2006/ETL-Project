# %%
from supabase import create_client
import pandas as pd, os
from dotenv import load_dotenv
load_dotenv()
supabase = create_client(os.getenv("SUPABASE_URL"), os.getenv("SUPABASE_KEY"))
data = supabase.table("iris_data").select("*").execute()
df = pd.DataFrame(data.data)
df.head()
df.info()
df.isnull().sum()
df.describe()
df.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             150 non-null    int64
#  1   sepal_length   150 non-null    float64
#  2   sepal_width    150 non-null    float64
#  3   petal_length   150 non-null    float64
#  4   petal_width    150 non-null    float64
#  5   species        150 non-null    object
#  6   sepal_ratio    150 non-null    float64
#  7   petal_ratio    150 non-null    float64
#  8   is_petal_long  150 non-null    int64
# dtypes: float64(6), int64(2), object(1)
# memory usage: 10.7+ KB
# Index(['id', 'sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species', 'sepal_ratio', 'petal_ratio', 'is_petal_long'],
#       dtype='object')

# %%
pip install supabase
# Out:
# Collecting supabaseNote: you may need to restart the kernel to use updated packages.
#
#   Downloading supabase-2.25.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting realtime==2.25.0 (from supabase)
#   Downloading realtime-2.25.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting supabase-functions==2.25.0 (from supabase)
#   Downloading supabase_functions-2.25.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting storage3==2.25.0 (from supabase)
#   Downloading storage3-2.25.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting supabase-auth==2.25.0 (from supabase)
#   Downloading supabase_auth-2.25.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting postgrest==2.25.0 (from supabase)
#   Downloading postgrest-2.25.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: httpx<0.29,>=0.26 in c:\users\radha\anaconda3\lib\site-packages (from supabase) (0.28.1)
# Collecting deprecation>=2.1.0 (from postgrest==2.25.0->supabase)
#   Using cached deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: pydantic<3.0,>=1.9 in c:\users\radha\anaconda3\lib\site-packages (from postgrest==2.25.0->supabase) (2.10.3)
# Collecting yarl>=1.20.1 (from postgrest==2.25.0->supabase)
#   Downloading yarl-1.22.0-cp313-cp313-win_amd64.whl.metadata (77 kB)
# Collecting pydantic<3.0,>=1.9 (from postgrest==2.25.0->supabase)
#   Downloading pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Collecting typing-extensions>=4.14.0 (from realtime==2.25.0->supabase)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting websockets<16,>=11 (from realtime==2.25.0->supabase)
#   Using cached websockets-15.0.1-cp313-cp313-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: pyjwt>=2.10.1 in c:\users\radha\anaconda3\lib\site-packages (from pyjwt[crypto]>=2.10.1->supabase-auth==2.25.0->supabase) (2.10.1)
# Collecting strenum>=0.4.15 (from supabase-functions==2.25.0->supabase)
#   Using cached StrEnum-0.4.15-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: anyio in c:\users\radha\anaconda3\lib\site-packages (from httpx<0.29,>=0.26->supabase) (4.7.0)
# Requirement already satisfied: certifi in c:\users\radha\anaconda3\lib\site-packages (from httpx<0.29,>=0.26->supabase) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\radha\anaconda3\lib\site-packages (from httpx<0.29,>=0.26->supabase) (1.0.9)
# Requirement already satisfied: idna in c:\users\radha\anaconda3\lib\site-packages (from httpx<0.29,>=0.26->supabase) (3.7)
# Requirement already satisfied: h11>=0.16 in c:\users\radha\anaconda3\lib\site-packages (from httpcore==1.*->httpx<0.29,>=0.26->supabase) (0.16.0)
# Collecting h2<5,>=3 (from httpx[http2]<0.29,>=0.26->postgrest==2.25.0->supabase)
#   Using cached h2-4.3.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting hyperframe<7,>=6.1 (from h2<5,>=3->httpx[http2]<0.29,>=0.26->postgrest==2.25.0->supabase)
#   Using cached hyperframe-6.1.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting hpack<5,>=4.1 (from h2<5,>=3->httpx[http2]<0.29,>=0.26->postgrest==2.25.0->supabase)
#   Using cached hpack-4.1.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\radha\anaconda3\lib\site-packages (from pydantic<3.0,>=1.9->postgrest==2.25.0->supabase) (0.6.0)
# Collecting pydantic-core==2.41.5 (from pydantic<3.0,>=1.9->postgrest==2.25.0->supabase)
#   Downloading pydantic_core-2.41.5-cp313-cp313-win_amd64.whl.metadata (7.4 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3.0,>=1.9->postgrest==2.25.0->supabase)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: packaging in c:\users\radha\anaconda3\lib\site-packages (from deprecation>=2.1.0->postgrest==2.25.0->supabase) (24.2)
# Requirement already satisfied: cryptography>=3.4.0 in c:\users\radha\anaconda3\lib\site-packages (from pyjwt[crypto]>=2.10.1->supabase-auth==2.25.0->supabase) (44.0.1)
# Requirement already satisfied: cffi>=1.12 in c:\users\radha\anaconda3\lib\site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->supabase-auth==2.25.0->supabase) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\radha\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->supabase-auth==2.25.0->supabase) (2.21)
# Requirement already satisfied: multidict>=4.0 in c:\users\radha\anaconda3\lib\site-packages (from yarl>=1.20.1->postgrest==2.25.0->supabase) (6.1.0)
# Requirement already satisfied: propcache>=0.2.1 in c:\users\radha\anaconda3\lib\site-packages (from yarl>=1.20.1->postgrest==2.25.0->supabase) (0.3.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\radha\anaconda3\lib\site-packages (from anyio->httpx<0.29,>=0.26->supabase) (1.3.0)
# Downloading supabase-2.25.0-py3-none-any.whl (16 kB)
# Downloading postgrest-2.25.0-py3-none-any.whl (21 kB)
# Downloading realtime-2.25.0-py3-none-any.whl (22 kB)
# Downloading storage3-2.25.0-py3-none-any.whl (26 kB)
# Downloading supabase_auth-2.25.0-py3-none-any.whl (48 kB)
# Downloading supabase_functions-2.25.0-py3-none-any.whl (8.5 kB)
# Using cached h2-4.3.0-py3-none-any.whl (61 kB)
# Using cached hpack-4.1.0-py3-none-any.whl (34 kB)
# Using cached hyperframe-6.1.0-py3-none-any.whl (13 kB)
# Downloading pydantic-2.12.5-py3-none-any.whl (463 kB)
# Downloading pydantic_core-2.41.5-cp313-cp313-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    --------------- ------------------------ 0.8/2.0 MB 2.4 MB/s eta 0:00:01
#    ------------------------- -------------- 1.3/2.0 MB 3.1 MB/s eta 0:00:01
#    ------------------------------------ --- 1.8/2.0 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 2.4 MB/s eta 0:00:00
# Using cached websockets-15.0.1-cp313-cp313-win_amd64.whl (176 kB)
# Using cached deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Using cached StrEnum-0.4.15-py3-none-any.whl (8.9 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading yarl-1.22.0-cp313-cp313-win_amd64.whl (86 kB)
# Installing collected packages: strenum, yarl, websockets, typing-extensions, hyperframe, hpack, deprecation, typing-inspection, pydantic-core, h2, pydantic, supabase-functions, supabase-auth, storage3, realtime, postgrest, supabase
#
#   Attempting uninstall: yarl
#
#     Found existing installation: yarl 1.18.0
#
#     Uninstalling yarl-1.18.0:
#
#       Successfully uninstalled yarl-1.18.0
#
#    ---- -----------------------------------  2/17 [websockets]
#   Attempting uninstall: typing-extensions
#    ---- -----------------------------------  2/17 [websockets]
#    ------- --------------------------------  3/17 [typing-extensions]
#     Found existing installation: typing_extensions 4.12.2
#    ------- --------------------------------  3/17 [typing-extensions]
#     Uninstalling typing_extensions-4.12.2:
#    ------- --------------------------------  3/17 [typing-extensions]
#    ------- --------------------------------  3/17 [typing-extensions]
#    ------- --------------------------------  3/17 [typing-extensions]
#    ------- --------------------------------  3/17 [typing-extensions]
#    ------- --------------------------------  3/17 [typing-extensions]
#    ------- --------------------------------  3/17 [typing-extensions]
#    ------- --------------------------------  3/17 [typing-extensions]
#    ------- --------------------------------  3/17 [typing-extensions]
#    ------- --------------------------------  3/17 [typing-extensions]
#    ------- --------------------------------  3/17 [typing-extensions]
#    ------- --------------------------------  3/17 [typing-extensions]
#    ------- --------------------------------  3/17 [typing-extensions]
#    ------- --------------------------------  3/17 [typing-extensions]
#    ------- --------------------------------  3/17 [typing-extensions]
#    ------- --------------------------------  3/17 [typing-extensions]
#    ------- --------------------------------  3/17 [typing-extensions]
#    ------- --------------------------------  3/17 [typing-extensions]
#       Successfully uninstalled typing_extensions-4.12.2
#    ------- --------------------------------  3/17 [typing-extensions]
#    ---------------- -----------------------  7/17 [typing-inspection]
#   Attempting uninstall: pydantic-core
#    ---------------- -----------------------  7/17 [typing-inspection]
#     Found existing installation: pydantic_core 2.27.1
#    ---------------- -----------------------  7/17 [typing-inspection]
#     Uninstalling pydantic_core-2.27.1:
#    ---------------- -----------------------  7/17 [typing-inspection]
#       Successfully uninstalled pydantic_core-2.27.1
#    ---------------- -----------------------  7/17 [typing-inspection]
#    --------------------- ------------------  9/17 [h2]
#   Attempting uninstall: pydantic
#    --------------------- ------------------  9/17 [h2]
#     Found existing installation: pydantic 2.10.3
#    --------------------- ------------------  9/17 [h2]
#     Uninstalling pydantic-2.10.3:
#    --------------------- ------------------  9/17 [h2]
#       Successfully uninstalled pydantic-2.10.3
#    --------------------- ------------------  9/17 [h2]
#    ----------------------- ---------------- 10/17 [pydantic]
#    ----------------------- ---------------- 10/17 [pydantic]
#    ----------------------- ---------------- 10/17 [pydantic]
#    ----------------------- ---------------- 10/17 [pydantic]
#    ------------------------------ --------- 13/17 [storage3]
#    ----------------------------------- ---- 15/17 [postgrest]
#    ---------------------------------------- 17/17 [supabase]
#
# Successfully installed deprecation-2.1.0 h2-4.3.0 hpack-4.1.0 hyperframe-6.1.0 postgrest-2.25.0 pydantic-2.12.5 pydantic-core-2.41.5 realtime-2.25.0 storage3-2.25.0 strenum-0.4.15 supabase-2.25.0 supabase-auth-2.25.0 supabase-functions-2.25.0 typing-extensions-4.15.0 typing-inspection-0.4.2 websockets-15.0.1 yarl-1.22.0
